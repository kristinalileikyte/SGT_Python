# %% [markdown]
# # Task:
# Create the Python program which:
# 1) Reads the data from data source - the file from Web or the data from Web scrapping.
# 2) Data must be processed in Python using Pandas.
# 3) Do the necessary data transformations in Pandas.
# 4) Visualize the data.
# 5) Save the data results (tables and plots) in the files (JSON and CSV) and as Markdown HTML/PDF file in Jupyter.
# 5) Create database using SQL (MySQL) and store/update the data there.

# %% [markdown]
# ## Processing data in Python using Pandas

# %% [markdown]
# ### Importing library

# %%
import pandas as pd

# %% [markdown]
# ### Loading a dataset using Pandas

# %%
data = pd.read_csv("Kaunas_hotels_list.csv")

# %%
pd.set_option('display.max_rows',300)

# %%
data
# Out:
#                                                   name  price score
# 0                                   Moxy Kaunas Center   € 77   9.0  \
# 1                                          Kaunas City   € 76   8.7
# 2                                     The house Kaunas   € 50   8.4
# 3                                       Hostel Liberty   € 30   8.1
# 4                                R plius "Easy Kaunas"   € 42   8.7
# 5                                      Villa Kaunensis   € 53   8.7
# 6                                         Berman House   € 61   9.3
# 7                                         Bōheme House  € 117   9.1
# 8                                 Oak house apartments   € 47   8.9
# 9                                            Happy Inn   € 40   7.2
# 10                               Radisson Hotel Kaunas   € 99   8.8
# 11                         BEST WESTERN Santakos Hotel  € 141   8.1
# 12                                       Olympus Hotel   € 59   8.7
# 13                                     Hotel Babilonas   € 63   7.5
# 14                                          Hostel Lux   € 29   8.8
# 15                                      Mr Jo’s hostel   € 40   8.4
# 16                                   Kaunas Apartments   € 43   8.1
# 17                        Laisves ave. Apartments Mini   € 72   9.5
# 18                                  Ibis Kaunas Centre   € 81   8.0
# 19                              River house apartments   € 41   8.5
# 20                                        Algiro Hotel   € 76   9.0
# 21                                     Very Bad Hootel   € 71   9.3
# 22                                              Family   € 66   8.8
# 23                        Green Hill Valley apartments  € 160   9.1
# 24                                        Algiro Hotel   € 76   9.0
# 25                                              Family   € 66   8.8
# 26                        Green Hill Valley apartments  € 160   9.1
# 27                          Extra Hostel "Easy Kaunas"   € 35   7.0
# 28                          Amberton Cozy Hotel Kaunas   € 87   7.8
# 29                        Green apartments Easy Kaunas   € 46   8.9
# 30                           Savan House "Easy Kaunas"   € 32   8.0
# 31                    DP Art Residence - self check in   € 57   9.1
# 32                 Laisves Avenue Hostel "Easy Kaunas"   € 34   8.6
# 33                             Laisves ave. Apartments   € 98   9.7
# 34       Apartments near old town with private parking   € 47   9.4
# 35                                  BEST BALTIC Kaunas  € 115   7.8
# 36   Downtown Ministery - luxury apartments in the ...  € 222   9.4
# 37                                J&E NERIES Apartment  € 100   9.5
# 38                                       Inner Blossom  € 122   9.7
# 39                         A&L private rooms in Kaunas   € 41   7.5
# 40                           Kaunas Old Town Apartment  € 145   8.6
# 41                                    Nemuno Apartment   € 87   9.2
# 42                                 Nemuno Apartamentai   € 79   8.9
# 43                                Maironis apartment 2  € 182   9.4
# 44                              Nemunas Tour Residence   € 73   8.9
# 45                                              Kaunas  € 152   8.9
# 46                                      Stay in Kaunas   € 65   9.5
# 178              2     Very Good
# 179             35   Exceptional
# 180             53   Exceptional
# 181             75     Wonderful
# 182             48     Wonderful
# 183            458     Very Good
# 184             11  Review score
# 185             28  Review score
# 186             29     Excellent
# 187             50     Excellent
# 188             27     Excellent
# 189              1     Very Good
# 190             14     Wonderful
# 191             62     Excellent
# 192            668          Good
# 193            633     Wonderful
# 194            154  Review score

# %% [markdown]
# ### Cleaning data

# %%
# Formating all float values
pd.options.display.float_format = '{:,.1f}'.format

# %%
# Checking data type of score column values
data['score'].apply(type).value_counts()
# Out:
# score
# <class 'str'>    195
# Name: count, dtype: int64

# %%
# Removing 'E' values and replacing column type to float
data['score'] = data['score'].replace("E","",regex=True).astype('float')

# %%
# Checking data type of price column
data['price'].apply(type).value_counts()
# Out:
# price
# <class 'str'>    195
# Name: count, dtype: int64

# %%
# Removing currency signs (€) and replacing column type to float
data['price'] = data['price'].replace("€","",regex=True).astype('float')

# %%
# Checking data type of reviews amount column
data['reviews amount'].apply(type).value_counts()
# Out:
# reviews amount
# <class 'str'>    195
# Name: count, dtype: int64

# %%
# Removing commas and replacing column type to int
data['reviews amount'] = data['reviews amount'].replace(",","",regex=True).astype('int')

# %%
# Checking data type of reviews column
data['review'].apply(type).value_counts()
# Out:
# review
# <class 'str'>    195
# Name: count, dtype: int64

# %%
# Replacing 'xceptional' strings with 'Exceptional' in review score column
data['review'].replace("xceptional", "Exceptional", inplace=True)

# %%
# Disabling SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %%
# Converting all review column values with review score less than 7.0 to 'Fair' and with less than 6.0 to 'Poor'
counter = 0
for row in data['score']:
    if row < 6:
        data['review'][counter] = "Poor"
    elif row >= 6 and row < 7:
        data['review'][counter] = "Fair"
    counter += 1

# %% [markdown]
# ### Renaming columns

# %%
data.rename(columns = {'price':'price(eur)','reviews amount':'reviews_amount'}, inplace = True)
data
# Out:
#                                                   name  price(eur)  score
# 0                                   Moxy Kaunas Center        77.0    9.0  \
# 1                                          Kaunas City        76.0    8.7
# 2                                     The house Kaunas        50.0    8.4
# 3                                       Hostel Liberty        30.0    8.1
# 4                                R plius "Easy Kaunas"        42.0    8.7
# 5                                      Villa Kaunensis        53.0    8.7
# 6                                         Berman House        61.0    9.3
# 7                                         Bōheme House       117.0    9.1
# 8                                 Oak house apartments        47.0    8.9
# 9                                            Happy Inn        40.0    7.2
# 10                               Radisson Hotel Kaunas        99.0    8.8
# 11                         BEST WESTERN Santakos Hotel       141.0    8.1
# 12                                       Olympus Hotel        59.0    8.7
# 13                                     Hotel Babilonas        63.0    7.5
# 14                                          Hostel Lux        29.0    8.8
# 15                                      Mr Jo’s hostel        40.0    8.4
# 16                                   Kaunas Apartments        43.0    8.1
# 17                        Laisves ave. Apartments Mini        72.0    9.5
# 18                                  Ibis Kaunas Centre        81.0    8.0
# 19                              River house apartments        41.0    8.5
# 20                                        Algiro Hotel        76.0    9.0
# 21                                     Very Bad Hootel        71.0    9.3
# 80                       Petro delux apartments center        74.0    9.9
# 81                                Diamond svečių namai        92.0   10.0
# 82                                       Kaunas Garden        68.0    8.7
# 83                              Kaunas Heart Apartment       126.0   10.0
# 84                                         Knygų namai        61.0    9.8
# 85       Courtyard gallery apartment with free parking        82.0   10.0
# 86          Zalgirio Arena Apartment No1 by URBAN RENT        74.0    9.1
# 87                             Old Slabada Loft Kaunas        73.0    9.8
# 88                                          Daukanto 5       182.0    9.7
# 89                         Stay in Kaunas & Radio City        66.0    9.8
# 90               Luxury Queen V apartment with Jacuzzi       502.0    9.7
# 91                                         Quiet place        47.0    9.6
# 92                                  Jurgis Guest house        40.0    7.1
# 93                                           Čepinskio        62.0    9.5
# 94                        Green Hill Valley apartments       160.0    9.1
# 95                Small attic rooms in Kaunas old town        53.0    8.3
# 96                                  IBIS Styles Kaunas       104.0    9.0
# 97                                    City Center loft       112.0    9.5
# 98     RIVERFRONT 2BD Old Town Apartment by Hostlovers       133.0    6.5
# 99                  Clinic 1BD Apartment by Hostlovers        69.0    8.8
# 100      Courtyard gallery apartment with free parking        82.0   10.0
# 101                        Stay in Kaunas & Radio City        66.0    9.8
# 102                                         Life Story        66.0    9.8
# 103                                      Kaunas Garden        68.0    8.7
# 104                                   Nemuno Apartment        87.0    9.2
# 105                             Old Slabada Apartments        52.0    9.3
# 106                                Center studio hause        81.0    9.4
# 107                                    Raudondvario II        58.0    9.1
# 108                                             M Loft        72.0    9.4
# 109                          Kaunas Old Town Apartment        70.0    9.7
# 110          Central Apartment in Architectural Street        95.0    9.8
# 111                                   Laisves alley 50        63.0    8.5
# 112                          Kauko Laiptų Apartamentai        76.0    9.4
# 113                 Apartment with jacuzzi in Old Town        65.0    8.5
# 114  Minimalist Studio Apartments in Old Town by Ho...        78.0    7.7
# 115         Zalgirio Arena Apartment No1 by URBAN RENT        74.0    9.1
# 116                                     KaunasInn - AM        87.0    9.0
# 117                                      Donelaičio 42        57.0    7.7
# 118                         Mickeviciaus str apartment        53.0    9.0
# 119                              Kotedžai Milikonių g.        64.0    7.0
# 120                          Apartamentai Lampėdžiuose        50.0    8.8
# 121                                     KaunasInn - AM        87.0    9.0
# 122                           Gallery Balta Apartments       124.0    9.5
# 123                                         Pas Birute        47.0    8.2
# 124                               Alanta "Easy Kaunas"        40.0    8.6
# 125  Apartments in Kaunas city centre with Jacuzzi ...       167.0    8.5
# 126                                             M Loft        72.0    9.4
# 127                                     HappyInn Rooms        47.0    6.2
# 128                  Cosy little apartment, Eith floor        52.0   10.0
# 129                               Maple Park Apartment        84.0    9.9
# 130          Central Apartment in Architectural Street        90.0    9.8
# 131                               Apartments in Kaunas        45.0    7.1
# 132                                    Raudondvario II        58.0    9.1
# 133                      Alanta Apartments Easy Kaunas        53.0    8.9
# 134                                    Baltosios Bures       282.0    7.9
# 135                                         Life Story        66.0    9.8
# 136                          Kaunas Old Town Apartment        70.0    9.7
# 137                                 Old town apartment        95.0   10.0
# 122              70  Exceptional
# 123              40    Very Good
# 124            1032    Excellent
# 125              62    Very Good
# 126             118    Wonderful
# 127             223         Fair
# 128               1  Exceptional
# 129               8  Exceptional
# 130              43  Exceptional
# 131              11         Good
# 132             161    Wonderful
# 133              90    Excellent
# 134               9         Good
# 135              21  Exceptional
# 136              15  Exceptional
# 137              18  Exceptional
# 138             101    Wonderful
# 139              10    Wonderful
# 140              26  Exceptional
# 141              45         Good
# 142              23    Excellent
# 143               9         Good
# 144              37    Wonderful
# 145              22  Exceptional
# 146              31  Exceptional
# 147              29    Wonderful
# 148              37    Wonderful
# 149              39         Poor
# 150              90    Wonderful
# 151               3         Good
# 152              27    Excellent
# 153              93    Wonderful
# 154               2    Very Good
# 155              46         Good
# 156              75    Wonderful
# 157              75    Wonderful
# 158               4    Very Good
# 159              48    Wonderful
# 160              40    Very Good
# 161               5  Exceptional
# 162              29    Excellent
# 163               6  Exceptional
# 164              34    Excellent
# 165              62    Excellent
# 166              11         Good
# 167               5    Wonderful
# 168              50    Excellent
# 169              28         Poor
# 170              11         Poor
# 171               5    Excellent
# 172              10    Wonderful
# 173              27    Excellent
# 174              14    Wonderful
# 175              11         Good
# 176              39    Wonderful
# 177              30         Good
# 178               2    Very Good
# 179              35  Exceptional
# 180              53  Exceptional
# 181              75    Wonderful
# 182              48    Wonderful
# 183             458    Very Good
# 184              11         Poor
# 185              28         Poor
# 186              29    Excellent
# 187              50    Excellent
# 188              27    Excellent
# 189               1    Very Good
# 190              14    Wonderful
# 191              62    Excellent
# 192             668         Good
# 193             633    Wonderful
# 194             154         Poor

# %% [markdown]
# ## Calculating summary statistics for a dataset: mean, median, and standard deviation ##

# %%
# Mean value of a price column
data['price(eur)'].mean()
# Out:
# 87.13333333333334

# %%
# Median value of a price column
data['price(eur)'].median()
# Out:
# 72.0

# %%
# Standard deviation of a price column
data['price(eur)'].std()
# Out:
# 64.59958081848828

# %% [markdown]
# ## Sorting values in descending score and ascending price order

# %%
best_cheapest_hotels = data.sort_values(by=['score','price(eur)'], ascending = [False,True], ignore_index = True)
best_cheapest_hotels.iloc[:5]
# Out:
#                                                 name  price(eur)  score
# 0                  Cosy little apartment, Eith floor        52.0   10.0  \
# 1  Old Town apartment with underground parking an...        79.0   10.0
# 2      Courtyard gallery apartment with free parking        82.0   10.0
# 3      Courtyard gallery apartment with free parking        82.0   10.0
# 4                               Diamond svečių namai        92.0   10.0
#
#    reviews_amount       review
# 0               1  Exceptional
# 1               2  Exceptional
# 2               4  Exceptional
# 3               4  Exceptional
# 4               1  Exceptional

# %% [markdown]
# ## Visualizing data using Matplotlib

# %% [markdown]
# ### Importing libraries

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Adding prices to coresponding lists according to reviews

reviews = {'Exceptional':[],'Wonderful':[],'Excellent':[],
           'Very Good':[],'Good':[],'Fair':[],'Poor':[]}
count = 0
for row in data['review']:
    match row:
        case 'Exceptional':
            reviews['Exceptional'].append(data['price(eur)'][count])            
        case 'Wonderful':
            reviews['Wonderful'].append(data['price(eur)'][count])
        case 'Excellent':
            reviews['Excellent'].append(data['price(eur)'][count])
        case 'Very Good':
            reviews['Very Good'].append(data['price(eur)'][count])
        case 'Good':
            reviews['Good'].append(data['price(eur)'][count])
        case 'Fair':
            reviews['Fair'].append(data['price(eur)'][count])  
        case 'Poor':
            reviews['Poor'].append(data['price(eur)'][count])  
    count += 1
    
    
# Finding average, minimum and maximum values of the lists
reviews_prices = {
    'min_price' : np.array([]),
    'max_price' : np.array([])
}
reviews_prices_keys = []
reviews_amount_average = []

for key, value in reviews.items():
    if value:
        reviews_prices_keys.append(key)
        reviews_prices['min_price'] = np.append(reviews_prices['min_price'], min(value))
        reviews_prices['max_price'] = np.append(reviews_prices['max_price'], max(value))
        reviews_amount_average.append(sum(value)/len(value))

# %% [markdown]
# ### Stacked bar chart

# %%
# Stacked bar chart for representing minimum and the maximum prices of the hotels with the same review score

fig, ax = plt.subplots(figsize=(8, 5))
bottom = np.zeros(len(reviews_prices['min_price']))
colors = ['#24b1d1', '#ae24d1']

for review_name, prices in reviews_prices.items():
    p = ax.bar(list(reviews_prices_keys), prices, label=review_name, bottom=bottom, alpha=0.8)
    bottom += prices

ax.set_title("Minimum and maximum prices depending on hotels reviews")
plt.ylabel('Price €')
plt.xlabel('Reviews')
ax.legend(loc="upper right")

plt.show()

# %% [markdown]
# ### Simple plot

# %%
# Simple plot diagram for representing how the reviews score depends on the reviews amount

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(reviews_prices_keys,reviews_amount_average)

ax.set(xlabel='Reviews', ylabel='Average of reviews amount',
       title='Reviews score dependency on average of reviews amount')
ax.grid()

plt.show()

# %% [markdown]
# ### Scatter plot

# %%
# Scatter plot diagram for representing how the price of a hotel room depends on the feedback score

x = data['score']
y = data['price(eur)']

colors = np.random.rand(len(data['score']))

plt.scatter(x, y, c=colors, alpha=0.5)

plt.xlabel('Reviews score')
plt.ylabel('Price €')

plt.show()

# %% [markdown]
# ## Exporting data to local files

# %%
# Exporting data to JSON file
data.to_json(r'booking.json')

# %%
# Exporting data to CSV file
data.to_csv(r'booking.csv')

# %% [markdown]
# ## Exporting data via MySQL into database

# %% [markdown]
# ### Import libraries

# %%
from sqlalchemy import create_engine
import mysql.connector

# %% [markdown]
# ### Establishing connections to mysql

# %%
cnx = mysql.connector.connect(user='root',
                              password='',
                              host='localhost',
                              database='booking')

# %%
# Creating a cursor object
cursor = cnx.cursor()

# %%
engine = create_engine("mysql+pymysql://" + "root" + ":" + "@" + "localhost" + "/" + "booking")

# %% [markdown]
# ### Exporting dataframe to MySQL database

# %%
data.to_sql('hotels', engine, index=False, if_exists="replace")
# Out:
# 195

# %%
# Adding ID column as a primary key
query = ('ALTER TABLE hotels ADD COLUMN `id` int(10) unsigned primary KEY AUTO_INCREMENT FIRST;')
cursor.execute(query)

# %%
# Commiting changes
cnx.commit()

# %% [markdown]
# ### Closing connections

# %%
cursor.close()
cnx.close()
